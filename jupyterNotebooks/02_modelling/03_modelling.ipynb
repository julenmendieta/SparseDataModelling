# %% [markdown]
# # Libraries and functions

# %%
import sys
import os
import shutil
import datetime

# %% [markdown]
# # Parameters to modify

# %%
## paths. Avoid paths with white spaces or _
# Location of the base folder downloaded from GitHub
basePath = '/home/julen/TADdyn/TADdyn_tutorial/'


## Execution parameters
# days-hours:minutes:seconds of maximum running time of the process
jobTime = '0-08:00:00' 
# how many models will we create
nmodels = 1500
# Steps in which you wnat to divide the modelling (to divide the modelling
# in n steps and save the output)
steps = 20
# How many CPU's will we allow for the process
ncpu = 26

#If we set outputAppart to False the models will be stored inside of a folder 
# called finalModels inside of the same folder as the matrix. If set to True, 
# models will be stored in a folder called "models" at the same level of the 
# folder called "matrices".
outputAppart = True

# %% [markdown]
# # Run

# %% [markdown]
# ## Define additional paths

# %%
scriptsPath = basePath + 'code/modellingScripts/'
GeneralOptimOutPath = basePath + 'optimization/'
tempOut = basePath + 'temporal/modelling'

# %% [markdown]
# ## Import additional libraries

# %%
sys.path.append(basePath + 'code')
import metrics

# %% [markdown]
# ## Recover best optimization parameters

# %% [markdown]
# Here we will recover the top parameters for the final ensemble of models, calculate the time needed to compute all models and get a variable with the commands to run. These parameters were defined in 02_chooseBestParameters.ipynb

# %%
# Load modelling info
cmds, times = metrics.getModellingCommand(GeneralOptimOutPath, tempOut, jobTime,
                       nmodels, ncpu, outputAppart, scriptsPath, step=steps)

# %%
# get expected modelling time
totalTime2 = str(datetime.timedelta(seconds=times))
print("Stimated time with assigned number of %s CPU's: %s" %(ncpu,
                                    totalTime2))
# Out:
# Stimated time with assigned number of 26 CPU's: 12:57:13.269231

# %% [markdown]
# ## Reconstruct the 3D organisation of the chromatin

# %% [markdown]
# This code will produce the models (.modelsTemp files) and merge them (in case were done in steps) into a .TADdynDict file. If previous runs with the same combinations of parameters are found in the folder, will also be merged. Merged files will be erased

# %%
# Make models (results in .model files)
for nc, cmd in enumerate(cmds):
    print('Run %s of %s' %(nc + 1), len(cmds))
    ! python {cmd}
    
# Merge, filter, and delete .model files
# This step is important since files finishing in .models
# can be overwriten in future modelling runs
outpaths = set()
for cmd in cmds:
    outpaths.add(cmd.split()[-1])
print('--- Merging ---')
for out in outpaths:
    print(out)
    cmd = '%s06_combineModels.py %s' %(scriptsPath, out)
    ! python {cmd}
# Out:
# Run 1
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_2 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_2.models
# Run 2
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_4 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_4.models
# Run 3
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_7 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_7.models
# Run 4
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_11 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_11.models
# Run 5
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_16 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_16.models
# Run 6
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_22 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_22.models
# Run 7
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_29 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_29.models
# Run 8
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_37 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_37.models
# Run 9
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_46 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_46.models
# Run 10
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_56 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_56.models
# Run 11
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_67 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_67.models
# Run 12
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_79 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_79.models
# Run 13
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_92 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_92.models
# Run 14
# We dont consider floating points in maxdist: 300.0
# WARNING: this is an empty shell, no data here.
# Preparing to model 942 particles
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Unknown error with process
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# Performing minimization run...
# /scratch/julen/TADdyn_tutorial/temporal/temporal_106 /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/Ery_b-globin-200All_200.0L0.0U0.0M300Res5000_106.models
# --- Merging ---
# /scratch/julen/TADdyn_tutorial/models/Ery/b-globin/
# Ery_b-globin-200All_200.0L0.0U0.0M300Res5000
# 1237 models joined
# --- Deleting .model files ---

# %% [markdown]
# ## Clean temporal folders

# %% [markdown]
# The content inside of the generated temporal folders inside $tempOut is usually deleted after the modelling successfully finishes, not the folders itself though. Besides, if the modelling process breaks for any reason, the temporal files will remain there. TADdyn modelling generates a lot of temporal files so, in order to ensure that they don't accumulate, we will remove the container folders after each optimisation process.

# %%
tempFolders = os.listdir(basePath + 'temporal/')

# %%
for t in tempFolders:
    print t
    shutil.rmtree(basePath + 'temporal/%s' %t)
# Out:
# modelling_1
# modelling_6
# _3
# modelling_3
# modelling_10
# _10
# _6
# _1
